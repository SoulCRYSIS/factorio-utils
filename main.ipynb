# %%
import auto_merge_sprites

# === INPUTS ===
# The prefix for the output filenames
PREFIX = "nyxoleum"
# The destination directory (relative to project root)
# DESTINATION = f"graphics/entities/machines/{PREFIX}"
DESTINATION = f"graphics/entities/plants/{PREFIX}"

# Toggles for each component
INCLUDE_OBJECT = True
INCLUDE_SHADOW = True
INCLUDE_REFLECTION = True
INCLUDE_GLOW = True

auto_merge_sprites.main(
    prefix=PREFIX,
    destination=DESTINATION,
    include_object=INCLUDE_OBJECT,
    include_shadow=INCLUDE_SHADOW,
    include_reflection=INCLUDE_REFLECTION,
    include_glow=INCLUDE_GLOW,
    is_plant=True
)
# Out:
# Processing sprites for prefix: nyxoleum
# Destination: graphics/entities/plants/nyxoleum
# Mode: Plant (Generating extra copies)
# [Object] Found 6 frames. Size: 512x512
# [Object] Creating spritesheet: 1536x1024 (3x2)
# [Object] Saved to /Users/user01/Documents/factorio/virentis/graphics/entities/plants/nyxoleum/nyxoleum.png
# [Object] Created Plant copy: /Users/user01/Documents/factorio/virentis/graphics/entities/plants/nyxoleum/nyxoleum-harvest.png
# [Object] Created Plant copy: /Users/user01/Documents/factorio/virentis/graphics/entities/plants/nyxoleum/nyxoleum-normal.png
# [Shadow] Found 6 frames. Size: 512x512
# [Shadow] Creating spritesheet: 1536x1024 (3x2)
# [Shadow] Saved to /Users/user01/Documents/factorio/virentis/graphics/entities/plants/nyxoleum/nyxoleum-shadow.png
# [Shadow] Created Plant copy: /Users/user01/Documents/factorio/virentis/graphics/entities/plants/nyxoleum/nyxoleum-harvest-shadow.png
# [Reflection] Found 6 frames. Size: 552x552
# [Reflection] Creating spritesheet: 1656x1104 (3x2)
# [Reflection] Saved to /Users/user01/Documents/factorio/virentis/graphics/entities/plants/nyxoleum/nyxoleum-water-reflection.png
# [Glow] Found 6 frames. Size: 512x512
# [Glow] Creating spritesheet: 1536x1024 (3x2)
# [Glow] Saved to /Users/user01/Documents/factorio/virentis/graphics/entities/plants/nyxoleum/nyxoleum-glow.png
